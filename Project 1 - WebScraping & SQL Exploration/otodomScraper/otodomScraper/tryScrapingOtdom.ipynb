# %%
import requests
from bs4 import BeautifulSoup
import lxml
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
import lxml
from lxml import etree

# %% [markdown]
# ## using requests

# %%
url = 'https://www.otodom.pl/pl/wyniki/wynajem/mieszkanie/cala-polska'
header = {"upgrade-insecure-requests": "1",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Windows; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.114 Safari/537.36",
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
        'sec-ch-ua': '"Google Chrome";v="93", " Not;A Brand";v="99", "Chromium";v="93"',
        "sec-ch-ua-mobile": "?0",
        'sec-ch-ua-platform': '"macOS"',
        "sec-fetch-site": "none",
        "sec-fetch-mod": "",
        "sec-fetch-user": "?1",
        "accept-encoding": "gzip, deflate, br",
        "accept-language": "bg-BG,bg;q=0.9,en-US;q=0.8,en;q=0.7"}
proxy = []
response = requests.get(url, headers=header, proxies={'http':proxy})

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## using selenium

# %%
# from selenium.webdriver.edge.service import Service as EdgeService
# from webdriver_manager.microsoft import EdgeChromiumDriverManager

# Set up the Selenium browser for Edge (ensure you have the correct version of Edge WebDriver)
edge_options = Options()
webdriver_path = r'F:\programs\browsers\browser drivers\msedgedriver.exe'
service = Service(webdriver_path)
edge_options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
browser = webdriver.Edge(service=service, options=edge_options)
# Open the target page
browser.get(url)

# Wait for the page to fully load
time.sleep(5)  # Adjust sleep time if needed

# Get the page source and parse it with BeautifulSoup
AllListings_response_edge = browser.page_source
AllListings_listing_bs_edge = BeautifulSoup(AllListings_response_edge, 'lxml')

# Close the browser
browser.quit()

# %% [markdown]
# ## extract listings

# %%
bs = BeautifulSoup(response.content, 'lxml')
listings = bs.select('#__next > div.css-1bx5ylf.e50rtj23 > main > div > div.css-1d0gimt.e50rtj21 > div.css-feokcq.e50rtj24 > div.ef1jqb0.css-1cvir3j > div.css-1i43dhb.ef1jqb1 > div:nth-child(4) > ul > li')  
len(listings)
# Out:
# 38

# %%
listing = listings[0]
listing.get_text()
# Out:
# 'Dodane wczorajSpodobało Ci się to ogłoszenie?Napisz1 / 211800\xa0zł+ czynsz: 600\xa0zł/miesiącWyjątkowa kawalerka pełna zieleni wśród parkówul. Źródłowa 43, Fabryczna, Śródmieście, Łódź, łódzkieLiczba pokoi1 pokójPowierzchnia34 m²Piętro3 piętroZobacz opis ogłoszeniaDo wynajęcia bezpośrednio od właściciela i bez prowizji stylowe i wygodne mieszkanie w bloku Źródłowa 43.\r\nPrzed budynkiem park pełen starych drzew i hasających wiewiórek, bardzo cicho i zielono :-)\r\n...Oferta prywatnaPodbite'

# %%
bs = BeautifulSoup(response.content, 'lxml')
listings = bs.select('#__next > div.css-1bx5ylf.e50rtj23 > main > div > div.css-1d0gimt.e50rtj21 > div.css-feokcq.e50rtj24 > div.ef1jqb0.css-1cvir3j > div.css-1i43dhb.ef1jqb1 > div > ul > li')
len(listings)
# Out:
# 41

# %%
listing = listings[0]
listing.get_text()
# Out:
# 'Dodane wczorajSpodobało Ci się to ogłoszenie?Napisz1 / 211800\xa0zł+ czynsz: 600\xa0zł/miesiącWyjątkowa kawalerka pełna zieleni wśród parkówul. Źródłowa 43, Fabryczna, Śródmieście, Łódź, łódzkieLiczba pokoi1 pokójPowierzchnia34 m²Piętro3 piętroZobacz opis ogłoszeniaDo wynajęcia bezpośrednio od właściciela i bez prowizji stylowe i wygodne mieszkanie w bloku Źródłowa 43.\r\nPrzed budynkiem park pełen starych drzew i hasających wiewiórek, bardzo cicho i zielono :-)\r\n...Oferta prywatnaPodbite'

# %% [markdown]
# ## get listing page

# %%
listing_page = listing.select_one('article > section > div.css-13gthep.eeungyz2 > a').get('href')
listing_page_url = 'https://www.otodom.pl/' + listing_page
listing_page_url
# Out:
# 'https://www.otodom.pl//pl/oferta/wyjatkowa-kawalerka-pelna-zieleni-wsrod-parkow-ID4rKOz'

# %%
listing_response = requests.get(listing_page_url, headers=header)
listing_response.status_code
# Out:
# 200

# %%
listing_bs = BeautifulSoup(listing_response.content, 'lxml')

# %%
listing_bs.get_text()
# Out:
# '2 pokoje, mieszkanie na wynajem - Gdańsk, pomorskie - 65722068 • www.otodom.plKupujęNieruchomościMieszkaniaKawalerkiDomyDziałkiLokale\xa0użytkoweBiuraHale\xa0i\xa0magazynyGarażePopularne\xa0lokalizacjeWarszawaWrocławKrakówPoznańGdańskŁódźGdyniaKatowiceInwestycjeNowe\xa0mieszkaniaNowe\xa0domyNowe\xa0lokale\xa0użytkowePrzewodnik kupującegoDane Otodom Analytics: aktualne ceny ofertowe mieszkań i domów, ceny najmu i zwrot z inwestycji w 40 największych miastach...Praktyczne rozwiązania, które pomogą Ci wybrać mieszkanie...Uzyskaj dostęp do swojego Statusu Kredytowego w BIK…Zobacz wszystkieWynajmujęNieruchomościMieszkaniaKawalerkiDomyPokojeDziałkiLokale\xa0użytkoweBiuraHale\xa0i\xa0magazynyGarażePopularne\xa0lokalizacjeWarszawaWrocławKrakówPoznańGdańskŁódźGdyniaKatowicePopularne\xa0biura nieruchomościBiura nieruchomości w WarszawieBiura nieruchomości we WrocławiuBiura nieruchomości w KrakowieBiura nieruchomości w PoznaniuBiura nieruchomości w GdańskuBiura nieruchomości w ŁodziBiura nieru
# ...

# %%
parser = etree.HTMLParser()
listing_tree = etree.fromstring(listing_response.content, parser)

# %% [markdown]
# ## get listing page using selenium

# %%
# from selenium.webdriver.edge.service import Service as EdgeService
# from webdriver_manager.microsoft import EdgeChromiumDriverManager

# Set up the Selenium browser for Edge (ensure you have the correct version of Edge WebDriver)
edge_options = Options()
webdriver_path = r'F:\programs\browsers\browser drivers\msedgedriver.exe'
service = Service(webdriver_path)
edge_options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
browser = webdriver.Edge(service=service, options=edge_options)
# Open the target page
browser.get(listing_page_url)

# Wait for the page to fully load
time.sleep(5)  # Adjust sleep time if needed

contact_button = WebDriverWait(browser, 10).until(
    EC.element_to_be_clickable((By.CSS_SELECTOR, '#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > div.css-1t0wru6.e1mu8k271 > div.css-18folbk.e1mu8k275 > div > button'))
)
contact_button.click()

# Get the page source and parse it with BeautifulSoup
response_edge = browser.page_source
listing_bs_edge = BeautifulSoup(response_edge, 'lxml')
# Find the elements you're interested in
# listings_edge = listing_bs_edge.select('#grid-search-results > ul > li')

# Close the browser
browser.quit()

# %% [markdown]
# # get listing details

# %% [markdown]
# ## title

# %%
title = listing_bs.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > header > h1').get_text()
title
# Out:
# 'Premium, świetna lokalizacja, bezpośrednio'

# %% [markdown]
# ## location

# %%
location = listing_bs.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > header > div > a').get_text()
location
# Out:
# 'ul. Krzysztofa Komedy, Jasień, Gdańsk, pomorskie'

# %% [markdown]
# ## price

# %%
price = listing_bs.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > header > strong').get_text()
price

# %% [markdown]
# ## advert details

# %%
advert_details = listing_bs_edge.select('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > div:nth-child(3) > div > div')
for detail in advert_details:
    print(detail.get_text(separator=' '))
# Out:
# Powierzchnia 45 m²
# Czynsz 500 zł/miesiąc
# Liczba pokoi 2
# Kaucja 5 000 zł
# Piętro parter/3
# Rodzaj zabudowy blok
# Dostępne od Zapytaj
# Balkon / ogród / taras ogródek, taras
# Obsługa zdalna Zapytaj
# Stan wykończenia do zamieszkania

# %%
area = listing_bs_edge.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > div:nth-child(3) > div > div:nth-child(1) > div:nth-child(3) > div').get_text()
area
# Out:
# '34 m²'

# %%
rent = listing_bs_edge.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > div:nth-child(3) > div > div:nth-child(2) > div:nth-child(3) > div').get_text()
rent
# Out:
# '600 zł/miesiąc'

# %% [markdown]
# ## listing description

# %%
listing_description = listing_bs.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > section.css-1umupf3.eu82sls0 > div > div > div').get_text()
listing_description
# Out:
# 'Wynajmę bezpośrednio (bez prowizji dla agencji) luksusowe mieszkanie w najnowszej inwestycji Atal "Marcelin Zacisze".\nBlok został oddany do użytkowania w sierpniu 2023 roku.\nMieszkanie jest w pełni wyposażone i umeblowane z wykorzystaniem najwyższej jakości materiałów.\nOsiedle powstało w atrakcyjnej okolicy, dobrze skomunikowanej z najważniejszymi punktami miasta. Lokalizacja w pobliżu ul. Bukowskiej pozwala na szybki dojazd zarówno do centrum, jak i na lotnisko czy do Dworca Głównego. W pobliżu znajduje się Lasek Marceliński – las miejski, który oplatają kilometry ścieżek spacerowych i rowerowych. Mieszkanie zlokalizowane jest na parterze. Posiada utwardzony taras od strony salonu oraz trawę od strony sypialni.\nDuże okna doświetlają wnętrza. W oknach zainstalowane są automatyczne zewnętrzne rolety. Apartament składa się z sypialni, salonu z aneksem kuchennym oraz łazienki z wanną i prysznicem. Mieszkanie jest wyposażone w nowoczesny sprzęt AGD w tym:\npłytę indukcyjną\nzmywarkę
# ...

# %% [markdown]
# ## listing contacts - oops need selenium to press a button first to shot number

# %%
listing_contact = listing_bs.select_one('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > div.css-1t0wru6.e1mu8k271').get_text(separator=' ')
listing_contact
# Out:
# 'Bartek Oferta prywatna 608 Pokaż numer Wyślij wiadomość'

# %% [markdown]
# ## Additional information

# %%
additional_info = listing_bs_edge.select('#__next > main > div.css-zcvss4.eo3m6aa0 > div.css-y6l269.eo3m6aa3 > div:nth-child(9) > div > div')
for piece in additional_info:
    print(piece.get_text(separator='    '))
# Out:
# Typ ogłoszeniodawcy    prywatny
# Wynajmę również studentom    brak informacji
# Wyposażenie    zmywarka, lodówka, meble, piekarnik, kuchenka, pralka
# Media    telewizja kablowa, internet, telefon
# Ogrzewanie    miejskie
# Zabezpieczenia    drzwi / okna antywłamaniowe, domofon / wideofon, rolety antywłamaniowe
# Okna    plastikowe
# Winda    tak
# Miejsce parkingowe    garaż/miejsce parkingowe
# Rok budowy    2023
# Materiał budynku    brak informacji
# Informacje dodatkowe    brak informacji

# %%
['Opis',
                         '.css-1rkl5fg{font-size:12px;}@media '
                         '(min-width:992px){.css-1rkl5fg{font-size:14px;}}',
                         ".css-kuh8ep{position:relative;z-index:1;height:240px;overflow:hidden;}.css-kuh8ep::after{content:'';display:block;position:absolute;z-index:100;bottom:0;left:0;width:100%;height:40px;-webkit-transition:opacity "
                         '0.2s ease-out;transition:opacity 0.2s '
                         'ease-out;background-image:linear-gradient(rgb(255 '
                         '255 255 / 0%) 0%,rgb(255 255 255) '
                         '100%);pointer-events:none;}',
                         '.css-1wekrze{overflow-wrap:break-word;}',
                         'Witam! Wynajmę czyste i wygodne mieszkanie '
                         '2-pokojowe, idealne dla pary albo pary z '
                         'dzieckiem.\xa0Pokój z aneksem kuchennym plus '
                         'sypialnia, przedpokój i łazienka są bardzo '
                         'praktycznie rozłożone.\xa0Mieszkanie usytuowane jest '
                         'w bloku na Osiedlu Książąt Mazowieckich, na '
                         'parterze, blisko Centrum Handlowego Stacja Mława, '
                         'spokojne, przyjazne sąsiedztwo. W mieszkaniu na '
                         'podłogach panele, w łazience glazura, terakota, '
                         'oświetlenie punktowe, okna plastikowe. Mieszkanie '
                         'jest umeblowane i w pełni wyposażone, zabudowa '
                         'kuchenna, kuchnia gazowa+piekarnik, lodówka, '
                         'mikrofala, telewizor. Ponadto do dyspozycji najemcy '
                         'duży parking pod blokiem, gdzie zawsze bez żadnego '
                         'problemu jest miejsce. Oprócz galerii, tuż obok '
                         'sklep spożywczy, żabka, kościół, pasaż, szkoła '
                         'podstawowa, itp. Miesięczne wynajęcie to 1900 zł. '
                         'Dodatkowe koszty to opłaty za czynsz w wysokości 350 '
                         'zł i zużyte media - prąd, woda, gaz - według '
                         'licznika. Właściciel prosi o kaucję zwrotną w '
                         'wysokości 1900 zł. Więcej informacji chętnie udzielę '
                         'w prywatnej wiadomości.',
                         'Zapraszam!',
                         '.css-m1nyab{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;padding:12px '
                         '0;}',
                         '.css-gzi0hn{padding:12px '
                         '16px;border:none;outline:none;background:none;color:#00B54B;font-size:14px;font-weight:600;line-height:1;text-align:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;padding:12px '
                         '0;}.css-gzi0hn:hover,.css-gzi0hn:focus,.css-gzi0hn:active{-webkit-text-decoration:underline;text-decoration:underline;}.css-gzi0hn:disabled,.css-gzi0hn:disabled:hover,.css-gzi0hn:disabled:focus{color:#bdbdbd;-webkit-text-decoration:none;text-decoration:none;cursor:not-allowed;}',
                         '.css-111wug5{padding-right:8px;}',
                         'Pokaż więcej'][10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ['Opis',
#       2                          '.css-1rkl5fg{font-size:12px;}@media '
#       3                          '(min-width:992px){.css-1rkl5fg{font-size:14px;}}',
#       4                          ".css-kuh8ep{position:relative;z-index:1;height:240px;overflow:hidden;}.css-kuh8ep::after{content:'';display:block;position:absolute;z-index:100;bottom:0;left:0;width:100%;height:40px;-webkit-transition:opacity "
#       5                          '0.2s ease-out;transition:opacity 0.2s '
#       6                          'ease-out;background-image:linear-gradient(rgb(255 '
#       7                          '255 255 / 0%) 0%,rgb(255 255 255) '
#       8                          '100%);pointer-events:none;}',
#       9                          '.css-1wekrze{overflow-wrap:break-word;}',
# ...

# %%
 [".css-1pzgtql{margin:0;color:#1b232e;font-size:32px;font-weight:400;line-height:1.1;padding-top:32px;padding-bottom:16px;color:#212121;font-size:20px;font-weight:700;}.css-1pzgtql::before{content:'';display:block;padding-bottom:32px;border-top:1 "
                         'solid #e0e0e0;}',
                         'Opis',
                         '.css-1rkl5fg{font-size:12px;}@media '
                         '(min-width:992px){.css-1rkl5fg{font-size:14px;}}',
                         ".css-kuh8ep{position:relative;z-index:1;height:240px;overflow:hidden;}.css-kuh8ep::after{content:'';display:block;position:absolute;z-index:100;bottom:0;left:0;width:100%;height:40px;-webkit-transition:opacity "
                         '0.2s ease-out;transition:opacity 0.2s '
                         'ease-out;background-image:linear-gradient(rgb(255 '
                         '255 255 / 0%) 0%,rgb(255 255 255) '
                         '100%);pointer-events:none;}',
                         '.css-1wekrze{overflow-wrap:break-word;}',
                         'Mieszkanie jest nowe, komfortowo wykończone i '
                         'wyposażone, jeszcze nie było zasiedlone. Znajdują '
                         'się w nim wszystkie meble i niezbędne sprzęty AGD, '
                         'typu: lodówka, płyta indukcyjna, zmywarka, pralka, '
                         'piekarnik itp. Umeblowanie zgodne z załączonymi '
                         'zdjęciami. Składa się z salonu z aneksem '
                         'kuchennym,\xa0 trzech oddzielnych pokoi, łazienki, '
                         'oddzielnej toalety, garderoby i przedpokoju. '
                         'Mieszkanie znajduje się na II piętrze w nowo '
                         'wybudowanym, kameralnym\xa0 budynku przy ul. '
                         'Północnej 20a w Lublinie. Z dwóch pokoi oraz z '
                         'salonu jest wyjście na taras i na balkon.',
                         '\r\n',
                         'Mieszkanie jest wyposażone w klimatyzację, '
                         'instalację alarmową i wideofon. W budynku znajduje '
                         'się winda, istnieje też możliwość wynajmu miejsca '
                         'postojowego w garażu podziemnym. Ogrzewanie '
                         'miejskie. Budynek, w którym znajduje się mieszkanie '
                         'jest kameralny, parter + dwa piętra. W parterze '
                         'znajdują się 3 lokale usługowe przeznaczone pod '
                         'działalność medyczną, na pierwszym i drugim piętrze '
                         'znajduje się łącznie 5 mieszkań. Bardzo atrakcyjna '
                         'lokalizacja, w pobliżu wiele punktów usługowych, '
                         'placówek medycznych, łatwy dostęp do komunikacji '
                         'miejskiej. Wynajem bezpośrednio od właściciela, '
                         'wystawiam faktury. Zwierzęta nie są akceptowane. '
                         'Proszę o kontakt pod nr tel: 606 622 289 602505163, '
                         '604708070. Dostępne od zaraz, zapraszam do kontaktu.',
                         '.css-m1nyab{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;padding:12px '
                         '0;}',
                         '.css-gzi0hn{padding:12px '
                         '16px;border:none;outline:none;background:none;color:#00B54B;font-size:14px;font-weight:600;line-height:1;text-align:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;padding:12px '
                         '0;}.css-gzi0hn:hover,.css-gzi0hn:focus,.css-gzi0hn:active{-webkit-text-decoration:underline;text-decoration:underline;}.css-gzi0hn:disabled,.css-gzi0hn:disabled:hover,.css-gzi0hn:disabled:focus{color:#bdbdbd;-webkit-text-decoration:none;text-decoration:none;cursor:not-allowed;}',
                         '.css-111wug5{padding-right:8px;}',
                         'Pokaż więcej'][9]
# Out:
# '.css-gzi0hn{padding:12px 16px;border:none;outline:none;background:none;color:#00B54B;font-size:14px;font-weight:600;line-height:1;text-align:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;padding:12px 0;}.css-gzi0hn:hover,.css-gzi0hn:focus,.css-gzi0hn:active{-webkit-text-decoration:underline;text-decoration:underline;}.css-gzi0hn:disabled,.css-gzi0hn:disabled:hover,.css-gzi0hn:disabled:focus{color:#bdbdbd;-webkit-text-decoration:none;text-decoration:none;cursor:not-allowed;}'

# %%
import json

# %%
with open (r"F:\Library\Engineering\computer science\Data Science\portfolio projects\Project 2 - SQL Data Analytics\browser-headers.json", 'r') as file:
    headers_dict = json.load(file)

# %%
headers_dict['result']
# Out:
# [{'upgrade-insecure-requests': '1',
#   'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.10240',
#   'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#   'sec-ch-ua': 'Google Chrome;v="95", "Chromium";v="95", ";Not A Brand";v="99"',
#   'sec-ch-ua-mobile': '?0',
#   'sec-ch-ua-platform': 'Windows',
#   'sec-fetch-site': 'none',
#   'sec-fetch-mod': '',
#   'sec-fetch-user': '?1',
#   'accept-encoding': 'gzip',
#   'accept-language': 'en-US,it;q=0.7'},
#  {'upgrade-insecure-requests': '1',
#   'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
#   'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#   'sec-ch-ua': 'Google Chrome;v="84", "Chromium";v="84", ";Not A Brand";v="99"',
#   'sec-ch-ua-mobile': '?0',
# ...

# %%
if []:
    print ('koko')
# Out:
# koko

# %%
str([1234, 'koko'])
# Out:
# "[1234, 'koko']"

# %%
pattern = r'(\d\d+(?:[\.,]\d+)?)\s*(m2|sqm|m^2|m|m²)'

# Function to extract area from a given text
def extract_area(text):
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(0)
    return None
